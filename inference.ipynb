# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
os.environ["TORCH_CUDNN_V8_API_DISABLED"]="1"
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from memory_profiler import profile

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


@profile
def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

# %% [markdown]
# ## LJ Speech

# %%
hps = utils.get_hparams_from_file("./configs/ljs_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cuda()
_ = net_g.eval()

_ = utils.load_checkpoint("/home/latent/Downloads/pretrained_ljs.pth", net_g, None)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# INFO:root:Loaded checkpoint '/home/latent/Downloads/pretrained_ljs.pth' (iteration 0)

# %%
@profile
def run_vits():
    # stn_tst = get_text("VITS is Awesome!", hps)
    with torch.no_grad():
        stn_tst = torch.randint(0, 178, (30,))
        x_tst = stn_tst.cuda().unsqueeze(0)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
        audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
    #ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))

# %%
for _ in range(1000):
    run_vits()
# Out:
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499    927.6 MiB    927.6 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1044.1 MiB    116.5 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1044.1 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1044.1 MiB      0.0 MiB           1         g = None
#    506
#    507   1044.1 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1137.0 MiB     92.9 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1137.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1143.6 MiB      6.6 MiB           1       w_ceil = torch.ceil(w)
#    513   1143.6 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1143.6 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1143.6 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1143.6 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1143.6 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1143.6 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1143.6 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1176.5 MiB     32.9 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1196.3 MiB     19.8 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1196.3 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1196.3 MiB   1196.3 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1196.3 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1196.3 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1196.3 MiB      0.0 MiB           1         g = None
#    506
#    507   1196.3 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1196.3 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1196.3 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1196.3 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1196.3 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1196.3 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1196.3 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1196.3 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1196.3 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1196.3 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1196.3 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.7 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
# ...
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)
#
#
# ERROR: Could not find file /tmp/ipykernel_22448/2703944284.py
# Filename: /home/latent/asimVits/models.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#    499   1197.0 MiB   1197.0 MiB           1     @profile
#    500                                           def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
#    501   1197.0 MiB      0.0 MiB           1       x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#    502   1197.0 MiB      0.0 MiB           1       if self.n_speakers > 0:
#    503                                               g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#    504                                             else:
#    505   1197.0 MiB      0.0 MiB           1         g = None
#    506
#    507   1197.0 MiB      0.0 MiB           1       if self.use_sdp:
#    508   1197.0 MiB      0.0 MiB           1         logw = self.dp(x, x_mask, g=g, reverse=True, noise_scale=noise_scale_w)
#    509                                             else:
#    510                                               logw = self.dp(x, x_mask, g=g)
#    511   1197.0 MiB      0.0 MiB           1       w = torch.exp(logw) * x_mask * length_scale
#    512   1197.0 MiB      0.0 MiB           1       w_ceil = torch.ceil(w)
#    513   1197.0 MiB      0.0 MiB           1       y_lengths = torch.clamp_min(torch.sum(w_ceil, [1, 2]), 1).long()
#    514   1197.0 MiB      0.0 MiB           1       y_mask = torch.unsqueeze(commons.sequence_mask(y_lengths, None), 1).to(x_mask.dtype)
#    515   1197.0 MiB      0.0 MiB           1       attn_mask = torch.unsqueeze(x_mask, 2) * torch.unsqueeze(y_mask, -1)
#    516   1197.0 MiB      0.0 MiB           1       attn = commons.generate_path(w_ceil, attn_mask)
#    517
#    518   1197.0 MiB      0.0 MiB           1       m_p = torch.matmul(attn.squeeze(1), m_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    519   1197.0 MiB      0.0 MiB           1       logs_p = torch.matmul(attn.squeeze(1), logs_p.transpose(1, 2)).transpose(1, 2) # [b, t', t], [b, t, d] -> [b, d, t']
#    520
#    521   1197.0 MiB      0.0 MiB           1       z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#    522   1197.0 MiB      0.0 MiB           1       z = self.flow(z_p, y_mask, g=g, reverse=True)
#    523   1197.0 MiB      0.0 MiB           1       o = self.dec((z * y_mask)[:,:,:max_len], g=g)
#    524   1197.0 MiB      0.0 MiB           1       return o, attn, y_mask, (z, z_p, m_p, logs_p)

# %% [markdown]
# ## VCTK

# %%
hps = utils.get_hparams_from_file("./configs/vctk_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    n_speakers=hps.data.n_speakers,
    **hps.model).cuda()
_ = net_g.eval()

_ = utils.load_checkpoint("/path/to/pretrained_vctk.pth", net_g, None)

# %%
stn_tst = get_text("VITS is Awesome!", hps)
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    sid = torch.LongTensor([4]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, sid=sid, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))

# %% [markdown]
# ### Voice Conversion

# %%
dataset = TextAudioSpeakerLoader(hps.data.validation_files, hps.data)
collate_fn = TextAudioSpeakerCollate()
loader = DataLoader(dataset, num_workers=8, shuffle=False,
    batch_size=1, pin_memory=True,
    drop_last=True, collate_fn=collate_fn)
data_list = list(loader)

# %%
with torch.no_grad():
    x, x_lengths, spec, spec_lengths, y, y_lengths, sid_src = [x.cuda() for x in data_list[0]]
    sid_tgt1 = torch.LongTensor([1]).cuda()
    sid_tgt2 = torch.LongTensor([2]).cuda()
    sid_tgt3 = torch.LongTensor([4]).cuda()
    audio1 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt1)[0][0,0].data.cpu().float().numpy()
    audio2 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt2)[0][0,0].data.cpu().float().numpy()
    audio3 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt3)[0][0,0].data.cpu().float().numpy()
print("Original SID: %d" % sid_src.item())
ipd.display(ipd.Audio(y[0].cpu().numpy(), rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt1.item())
ipd.display(ipd.Audio(audio1, rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt2.item())
ipd.display(ipd.Audio(audio2, rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt3.item())
ipd.display(ipd.Audio(audio3, rate=hps.data.sampling_rate, normalize=False))
